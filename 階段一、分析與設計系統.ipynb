# %% [markdown]
# 各階段設計思路
# 最後更新：2022/07/10

# %% [markdown]
# # **階段一、分析與設計系統**
#
# 在階段零中，我們已經決定要使用28均線法則來做為篩選準則。
# 接下來我們需要分流程來設計系統，並逐一實現。
#
# 我大致將系統流程分為以下部分：
# > 初始設定(階段二) >> 查詢個股(階段三) >> 準則判斷(階段四)
#
#
# 初始設定：包含基本套件匯入、函式定義、各代數的預設初始給值及從證交所取回最新清單
# 查詢個股：包括查詢個股價格、成交量及計算各項判斷要有的各項指標
# 準則判斷：透過計算的指標進行判斷並匯入其對應的清單，後續將視情況通知匯出
